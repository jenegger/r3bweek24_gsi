# %%
#!/bin/python3
import matplotlib.pyplot as plt
import pandas as pd
import math
import numpy as np
import copy

# %% [markdown]
# ### function to calculate iso_corr_cross_section + stat. uncertainties

# %%
def stat_errors_neutron(filename,target_thickness):
    targettype = None
    factor = None
    n_t = None
    delta_n_t = None
    new_density = 1.851
    T_2198 = (new_density)*(2.1928)*(6.02214076)*(pow(10,23))/(12.011);
    T_1086 = (new_density)*(1.0793)*(6.02214076)*(pow(10,23))/(12.011);
    T_54 = (new_density)*(0.5451)*(6.02214076)*(pow(10,23))/(12.011);
    if (target_thickness == "thin"):
        targettype = "c_54"
        factor = (1./T_54)*(pow(10,27))
        n_t = T_54
        delta_n_t = 0.000648
    if (target_thickness == "medium"):
        targettype = "c_1086"
        n_t = T_1086
        delta_n_t = 0.002620
        factor = (1./T_1086)*(pow(10,27))
    if (target_thickness == "thick"):
        targettype = "c_2198"
        n_t = T_2198
        delta_n_t = 0.000322
        factor = (1./T_2198)*(pow(10,27))
        
    df = pd.read_csv(filename,sep='\t',names=["datatype","targettype","RunID","energy","d_reacted_carbon","all_carbon"])

    df["d_12c_survived"] = 1- df["d_reacted_carbon"]

    error_val = []
    iso_cs_val = []
    energy_vals = ["400","550","650","800"]
    for ene in energy_vals:
        d_iso = (float(df.loc[(df["targettype"] == targettype) & (df["energy"] == float(ene))]['d_12c_survived']))/(float(df.loc[(df["targettype"] == "empty") & (df["energy"] == float(ene))]['d_12c_survived']))

        iso_cs = factor*(-math.log(d_iso))

        #print("iso_cross_section:  ", iso_cs)
        r_survived_target = float(df.loc[(df["targettype"] == targettype) & (df["energy"] == float(ene))]['d_12c_survived']) 

        r_survived_empty = float(df.loc[(df["targettype"] == "empty") & (df["energy"] == float(ene))]['d_12c_survived'])
        n_i_t = float(df.loc[(df["targettype"] == targettype) & (df["energy"] == float(ene))]['all_carbon'])
        n_i_e = float(df.loc[(df["targettype"] == "empty") & (df["energy"] == float(ene))]['all_carbon'])
        target_error = pow(iso_cs*delta_n_t,2)
        #print(target_error)
        #print(iso_cs)
        iso_cs_val.append(iso_cs)
        #print("survived target\t",r_survived_target)
        counting_error = (pow(10,54))*(1./(n_t*n_t))*((1-r_survived_target)/(r_survived_target*n_i_t)+(1-r_survived_empty)/(r_survived_empty*n_i_e))
        #print(counting_error)
        #total_error = math.sqrt(target_error + counting_error) ## this is just true if you look indep. at iso cross section
        total_error = math.sqrt(counting_error)
        print("total error\t",total_error)

        error_val.append(total_error)
    return iso_cs_val,error_val

# %% [markdown]
# ### first method: MWPC2 and MWPC3 hit-level data
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_default.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")


fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
plt.savefig("iso_corr_cs_mw23_hit.png")
# Out:
# total error	 2.585306371366935
# total error	 3.449172635295736
# total error	 3.134590517949805
# total error	 3.6274476987109505
# total error	 1.4817736797335268
# total error	 2.024885883383382
# total error	 1.8360998307872674
# total error	 2.320191105468805
# total error	 0.873552402738251
# total error	 1.2197310956224872
# total error	 1.0969856217360714
# total error	 1.2017815135943317

# %% [markdown]
# ---

# %% [markdown]
# ### second method: MWPC2 and MWPC3 own clustered data
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_own_clustering.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")


fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
plt.savefig("iso_corr_cs_mw23_own_cluster.png")
# Out:
# total error	 3.084801766090009
# total error	 3.623321330883996
# total error	 3.019275945349004
# total error	 3.2145295929438373
# total error	 1.7325609579033996
# total error	 2.2466154719456486
# total error	 1.9982535007030333
# total error	 2.1194033979692897
# total error	 1.0203978867123922
# total error	 1.4315491500307977
# total error	 1.2293517156013967
# total error	 1.245789491603212

# %% [markdown]
# ---

# %% [markdown]
# ### third method: MWPC1 and MWPC3 hit-level data
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw13_default.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")


fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
plt.savefig("iso_corr_cs_mw13_hit.png")
# Out:
# total error	 2.7138123713464717
# total error	 3.63973704208218
# total error	 3.1038347183310466
# total error	 3.6618283876210445
# total error	 1.5758275717522345
# total error	 2.0638003239943274
# total error	 1.816523056590337
# total error	 2.173597549712462
# total error	 0.9182189524394172
# total error	 1.2477150602137421
# total error	 1.0891285476944286
# total error	 1.2330779559766134

# %% [markdown]
# ---

# %% [markdown]
# ### fourth method: MWPC1 and MWPC3 own clustered data
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw13_own_clustering.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")


fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
plt.savefig("iso_corr_cs_mw13_own_cluster.png")
# Out:
# total error	 2.766588653038523
# total error	 3.674336114289053
# total error	 3.0124533290140185
# total error	 3.150384244324408
# total error	 1.6577796405522263
# total error	 2.3160129466538395
# total error	 1.9316380213527244
# total error	 2.1071987478896577
# total error	 0.9865593872830123
# total error	 1.4115629598010746
# total error	 1.1745306838087444
# total error	 1.2161113417959932

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Quadrant check, using own clustering MW2/MW3

# %% [markdown]
# ---

# %%
ax_coll = []

# %% [markdown]
# ### Quadrant 4
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_quad4_own_clustering.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad4_thin, err_quad4_thin = iso_cs_thin,err_iso_thin
quad4_medium, err_quad4_medium = iso_cs_medium,err_iso_medium
quad4_thick, err_quad4_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
ax_coll.append(ax)
#ax.set_ylim(43,90)
# Out:
# total error	 6.990159581672206
# total error	 8.30519695382435
# total error	 6.701264314581776
# total error	 7.323148751959484
# total error	 4.141328344715887
# total error	 5.497541055113086
# total error	 4.1544439912467634
# total error	 4.704182076848511
# total error	 2.500978347706174
# total error	 3.445637746043398
# total error	 2.644713522057474
# total error	 2.832174358228706

# %% [markdown]
# ---

# %% [markdown]
# ### Quadrant 1
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_quad1_own_clustering.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad1_thin, err_quad1_thin = iso_cs_thin,err_iso_thin
quad1_medium, err_quad1_medium = iso_cs_medium,err_iso_medium
quad1_thick, err_quad1_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
ax_coll.append(ax)
# Out:
# total error	 6.8293288448333405
# total error	 6.408311879851406
# total error	 6.4429305076813375
# total error	 7.06167382372148
# total error	 3.956738536685452
# total error	 4.061325695029046
# total error	 4.162356966525753
# total error	 4.879215195795924
# total error	 2.3316886820007765
# total error	 2.691234202251419
# total error	 2.6366711820598967
# total error	 2.7208934932136444

# %% [markdown]
# ---

# %% [markdown]
# ### Quadrant 2
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_quad2_own_clustering.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad2_thin, err_quad2_thin = iso_cs_thin,err_iso_thin
quad2_medium, err_quad2_medium = iso_cs_medium,err_iso_medium
quad2_thick, err_quad2_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
ax_coll.append(ax)
# Out:
# total error	 6.0951517426079835
# total error	 6.777973587924547
# total error	 6.835035594358094
# total error	 7.164975043851616
# total error	 3.484157438752971
# total error	 4.2221075439475335
# total error	 4.249766695900204
# total error	 4.537623506617148
# total error	 1.9408930931594117
# total error	 2.6973239951128765
# total error	 2.5042942087265585
# total error	 2.489766782092636

# %% [markdown]
# ---

# %% [markdown]
# ### Quadrant 3
# ---

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_quad3_own_clustering.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad3_thin, err_quad3_thin = iso_cs_thin,err_iso_thin
quad3_medium, err_quad3_medium = iso_cs_medium,err_iso_medium
quad3_thick, err_quad3_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$')
#ax.set_ylim(43,90)
ax_coll.append(ax)
# Out:
# total error	 6.1919600024842545
# total error	 8.8259213775563
# total error	 6.246008561449996
# total error	 6.411101585739408
# total error	 3.425086791819835
# total error	 5.193654222839517
# total error	 3.9835632294825953
# total error	 4.188451907921629
# total error	 2.0728308036084733
# total error	 3.206561739440856
# total error	 2.4825266413560545
# total error	 2.396081383109789

# %% [markdown]
# ---

# %% [markdown]
# ### all Quadrants in one plot

# %%
fig, ax = plt.subplots(2,2,figsize=(15,7))

fig.tight_layout()

energy = [400,550,650,800]
ax[0,0].errorbar(energy,quad2_thick,yerr=err_quad2_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax[0,0].errorbar(energy,quad2_medium,yerr=err_quad2_medium,label="medium target",color='green',marker="o",fmt="o")
energy = [410,560,660,810]
ax[0,0].errorbar(energy,quad2_thin,yerr=err_quad2_thin,label="thin target",color='blue',marker="o",fmt="o")
ax[0,0].grid()

energy = [400,550,650,800]
ax[0,1].errorbar(energy,quad1_thick,yerr=err_quad1_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax[0,1].errorbar(energy,quad1_medium,yerr=err_quad1_medium,label="medium target",color='green',marker="o",fmt="o")
energy = [410,560,660,810]
ax[0,1].errorbar(energy,quad1_thin,yerr=err_quad1_thin,label="thin target",color='blue',marker="o",fmt="o")
ax[0,1].grid()

energy = [400,550,650,800]
ax[1,0].errorbar(energy,quad3_thick,yerr=err_quad3_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax[1,0].errorbar(energy,quad3_medium,yerr=err_quad3_medium,label="medium target",color='green',marker="o",fmt="o")
energy = [410,560,660,810]
ax[1,0].errorbar(energy,quad3_thin,yerr=err_quad3_thin,label="thin target",color='blue',marker="o",fmt="o")
ax[1,0].grid()

energy = [400,550,650,800]
ax[1,1].errorbar(energy,quad4_thick,yerr=err_quad4_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax[1,1].errorbar(energy,quad4_medium,yerr=err_quad4_medium,label="medium target",color='green',marker="o",fmt="o")
energy = [410,560,660,810]
ax[1,1].errorbar(energy,quad4_thin,yerr=err_quad4_thin,label="thin target",color='blue',marker="o",fmt="o")
ax[1,1].grid()

##set title of supfigures:
ax[0,0].set_title("Quadrant II")
ax[0,1].set_title("Quadrant II")
ax[1,0].set_title("Quadrant III")
ax[1,1].set_title("Quadrant IV")
for i in range(2):
    for j in range(2):
        ax[i,j].legend()
        ax[i,j].set_xlabel("Beam Energy [AMeV]")
        ax[i,j].set_ylabel("isotope correction factor [mbarn]")
        ax[i,j].set_ylim([35, 110])
fig.tight_layout()
plt.savefig("iso_corr_cs_mw23_own_cluster_all_quadrants.png")

# %% [markdown]
# ---

# %% [markdown]
# ### idea: clean up MW12-> diagonal cut, and plot then Quadrant4

# %%
f_name = "./with_stats_iso_corr/stats_inc_mw23_quad4_own_clustering_mw12_diag_cut.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad4_thin, err_quad4_thin = iso_cs_thin,err_iso_thin
quad4_medium, err_quad4_medium = iso_cs_medium,err_iso_medium
quad4_thick, err_quad4_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$, quadrant IV, diagonal cut on MW12')
ax_coll.append(ax)
#ax.set_ylim(43,90)
# Out:
# total error	 6.887248129979214
# total error	 8.306450437142875
# total error	 6.737194449403366
# total error	 7.239235744404963
# total error	 4.079464846464311
# total error	 5.475744861783081
# total error	 4.177713532289897
# total error	 4.621898818412331
# total error	 2.483810897820224
# total error	 3.438186488449756
# total error	 2.6333885523117995
# total error	 2.8109710323669

# %% [markdown]
# ---

# %% [markdown]
# ### Appendum: Roman's suggestion - first approx: only check center of MWX1 x-y, then apply correction

# %% [markdown]
# ---

# %%
f_name = "./with_stats_iso_corr/combined_iso_corr_center_own_cluster.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad4_thin, err_quad4_thin = iso_cs_thin,err_iso_thin
quad4_medium, err_quad4_medium = iso_cs_medium,err_iso_medium
quad4_thick, err_quad4_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$, quadrant IV, diagonal cut on MW12')
ax_coll.append(ax)
# Out:
# total error	 2.7306469527834016
# total error	 3.3426731597535766
# total error	 2.991580018438358
# total error	 3.1305132019433626
# total error	 1.639069913134109
# total error	 2.0892519861128744
# total error	 1.9354081859605432
# total error	 2.129717743723143
# total error	 0.9762890640011228
# total error	 1.3531180320740872
# total error	 1.1928922222011347
# total error	 1.23068373617834

# %% [markdown]
# ### Appendum: get 11C and 10C cross section from theory (EPAX)

# %% [markdown]
# ### 11C

# %%
f_name = "lise_11c_iso_corr.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
f_ref_400 = "lise_revised_11C.txt"
rev_thin,err_rev_thin = stat_errors_neutron(f_ref_400,"thin")
rev_medium, err_rev_medium= stat_errors_neutron(f_ref_400,"medium")
rev_thick,err_rev_thick = stat_errors_neutron(f_ref_400,"thick")


fig, ax = plt.subplots()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
ax.errorbar(energy,rev_thick,yerr=err_iso_thick,label="thick target",color='pink',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
ax.errorbar(energy,rev_medium,yerr=err_iso_medium,label="medium target",color='pink',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.errorbar(energy,rev_thin,yerr=err_iso_thin,label="thin target",color='pink',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C$, Theory Predictions LISE++ - EPAX')
ax_coll.append(ax)
# Out:
# total error	 0.9276578239594357
# total error	 0.9276366701176102
# total error	 0.9276366701176102
# total error	 0.9276366701176102
# total error	 0.6459946868834683
# total error	 0.6459713491584952
# total error	 0.645955790214568
# total error	 0.6459480106044143
# total error	 0.43432693795540184
# total error	 0.4342958804861133
# total error	 0.4342196393901426
# total error	 0.43422811126358757
# total error	 1.046249458583313
# total error	 1.046268236703653
# total error	 1.0462870144907197
# total error	 1.046268236703653
# total error	 0.7437304743548327
# total error	 0.7445836685333035
# total error	 0.7445769009146638
# total error	 0.7445769009146638
# total error	 0.523914640214597
# total error	 0.5239240684322134
# total error	 0.5239287824802585
# total error	 0.5238792829552785

# %% [markdown]
# ### 10C

# %%
f_name = "lise_revised_10C.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
fig, ax = plt.subplots()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{10}C$, Theory Predictions LISE++ - EPAX')
ax_coll.append(ax)
# Out:
# total error	 0.3399372952261527
# total error	 0.3399344198730176
# total error	 0.3399378702938518
# total error	 0.3399355700171612
# total error	 0.24161603871000123
# total error	 0.241618103663786
# total error	 0.24161748417949697
# total error	 0.24161831015818924
# total error	 0.16957208422195114
# total error	 0.16957707981122352
# total error	 0.16957850709554148
# total error	 0.1695628063104058

# %% [markdown]
# ### 11C +10C

# %%
#f_name = "lise_carbon_iso_corr.txt"
f_name = "lise_revised_carbon_iso_corr.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
iso_cs_theory,err_iso_theory = iso_cs_thin,err_iso_thin
print(iso_cs_theory)
fig, ax = plt.subplots()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$, Theory Predictions LISE++ - EPAX')
ax_coll.append(ax)
ax.set_ylim(37,65)
# Out:
# total error	 1.1003834551037024
# total error	 1.1004004267909158
# total error	 1.1004193633157113
# total error	 1.1004007840868053
# total error	 0.7824086440011052
# total error	 0.7832213048694306
# total error	 0.783214670289615
# total error	 0.783214927944223
# total error	 0.5512704505726858
# total error	 0.5512810043659723
# total error	 0.5512859443734565
# total error	 0.5512338476316782
# [61.16041256613147, 61.162296271651876, 61.16439809065544, 61.16233592861102]
# (37.0, 65.0)

# %% [markdown]
# ### ok, now first time with 1d projection and edges added up from the "good" side

# %% [markdown]
# #### taking the center and the edges

# %%
#f_name = "./with_stats_iso_corr/comb_one_d_iso_corr_with_edges.txt"
#f_name = "./with_stats_iso_corr/comb_oned_3g_puzzle.txt"

#f_name = "./with_stats_iso_corr/comb_try_july.txt"
#f_name = "./with_stats_iso_corr/comb_two_try_july.txt"
#f_name = "./with_stats_iso_corr/runwise_adjusted_iso_corr.txt"
#f_name = "./with_stats_iso_corr/runwise_adjusted_iso_corr_special.txt"

f_name = "./with_stats_iso_corr/runwise_fine_tuned_comb_test7.txt"


#f_name = "./with_stats_iso_corr/comb_one_d_3g_plus_manual_puzzle.txt" ## so far this does not work well
#f_name = "./with_stats_iso_corr/comb_oned_3g_center_part.txt"

#f_name = "./with_stats_iso_corr/comb_oned_3g_puzzle_tune.txt"

#f_name = "./with_stats_iso_corr/special.txt"


iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad4_thin, err_quad4_thin = iso_cs_thin,err_iso_thin
quad4_medium, err_quad4_medium = iso_cs_medium,err_iso_medium
quad4_thick, err_quad4_thick = iso_cs_thick,err_iso_thick

print(err_iso_thick)
print(iso_cs_thick)

fig, ax = plt.subplots(figsize=(15,10))
#fig.tight_layout()
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o",markersize=9)
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o",markersize=9)
ax.errorbar(energy,iso_cs_theory,yerr=err_iso_theory,label="EPAX 3.1a",color='black',marker="D",fmt="o",markersize=9)
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o",markersize=9)

handles, labels = plt.gca().get_legend_handles_labels()
order = [0,1,3,2]
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],fontsize=20,loc="upper left")

#ax.legend()
ax.grid()
ax.tick_params(labelsize=20)
ax.set_xlabel("Beam Energy [AMeV]",fontsize=20)
ax.set_ylabel("Cross Section Contribution [mbarn]",fontsize=20)
#ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$, central part, diagonal cut on MW12')
#ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$, central part + borders, diagonal cut on MW12')
ax_coll.append(ax)
plt.savefig("iso_corr_contribution_plot.png",dpi=300)
# Out:
# total error	 2.7094601351908496
# total error	 3.1002099837141652
# total error	 2.806411966013181
# total error	 3.4644560945057283
# total error	 1.543651843759919
# total error	 1.8541301982162839
# total error	 1.687122699274827
# total error	 2.0949410205819037
# total error	 0.8776667926053614
# total error	 1.1321331922430058
# total error	 0.9945353163500329
# total error	 1.1274153382238168
# [0.8776667926053614, 1.1321331922430058, 0.9945353163500329, 1.1274153382238168]
# [59.42721515484114, 70.16578163227967, 62.60260276028416, 61.619293168591156]

# %% [markdown]
# ### save results and errors as file

# %%
# Define dictionaries for each target thickness
thin_dict = {
    400: "0179_0001",
    550: "0099_0001",
    650: "0126_0001",
    800: "0166_0001"
}

medium_dict = {
    400: "0181_0001",
    550: "0101_0001",
    650: "0127_0001",
    800: "0168_0001"
}

thick_dict = {
    400: "0183_0001",
    550: "0103_0001",
    650: "0130_0001",
    800: "0170_0001"
}

extra_dict = {
    400: "0333_0001",
    550: "0344_0001",
    650: "0355_0001",
    800: "0366_0001"
}

# Mapping thickness to corresponding dictionary
thickness_map = {
    "thin": thin_dict,
    "medium": medium_dict,
    "thick": thick_dict,
    "extra": extra_dict
}
thickness_code = {
    "thin": "c_54",
    "medium": "c_1086",
    "thick": "c_2198",
    "extra": "extra"    
}

# Function to create the DataFrame
def get_file_cross_sec(list_cs, list_err, target_thickness):
    d = {'datatype': [], 'targettype': [], "RunID": [], "energy": [], "cross_sec": [], "error": []}
    df = pd.DataFrame(data=d)
    energy_vals = [400, 550, 650, 800]
    
    # Choose correct dictionary
    try:
        selected_dict = thickness_map[target_thickness]
    except KeyError:
        raise ValueError(f"Invalid target_thickness: {target_thickness}. Must be one of {list(thickness_map.keys())}")
    
    for i, ene in enumerate(energy_vals):
        runid = selected_dict[ene]
        df = df.append({
            "datatype": "exp",
            "targettype": thickness_code[target_thickness],
            "RunID": runid,
            "energy": ene,
            "cross_sec": list_cs[i],
            "error": list_err[i]
        }, ignore_index=True)
        
    return df
         
                
df_corr_thin = get_file_cross_sec(iso_cs_thin,err_iso_thin,"thin")  
df_corr_medium = get_file_cross_sec(iso_cs_medium,err_iso_medium,"medium")
df_corr_thick = get_file_cross_sec(iso_cs_thick,err_iso_thick,"thick")
df_all = pd.concat([df_corr_thin, df_corr_medium, df_corr_thick], ignore_index=True)   
print(df_all)
df_all.to_csv("iso_corr_output_cc_cs_final.txt", sep='\t', index=False, header=False)
# Out:
#    datatype targettype      RunID  energy  cross_sec     error
# 0       exp       c_54  0179_0001   400.0  70.813377  2.709460
# 1       exp       c_54  0099_0001   550.0  69.731190  3.100210
# 2       exp       c_54  0126_0001   650.0  59.452853  2.806412
# 3       exp       c_54  0166_0001   800.0  77.443710  3.464456
# 4       exp     c_1086  0181_0001   400.0  68.939587  1.543652
# 5       exp     c_1086  0101_0001   550.0  72.962136  1.854130
# 6       exp     c_1086  0127_0001   650.0  69.239323  1.687123
# 7       exp     c_1086  0168_0001   800.0  66.862865  2.094941
# 8       exp     c_2198  0183_0001   400.0  59.427215  0.877667
# 9       exp     c_2198  0103_0001   550.0  70.165782  1.132133
# 10      exp     c_2198  0130_0001   650.0  62.602603  0.994535
# 11      exp     c_2198  0170_0001   800.0  61.619293  1.127415

# %% [markdown]
# #### taking only the center

# %%
f_name = "./with_stats_iso_corr/comb_one_d_iso_corr_center_only.txt"
iso_cs_thin,err_iso_thin = stat_errors_neutron(f_name,"thin")
iso_cs_medium, err_iso_medium= stat_errors_neutron(f_name,"medium")
iso_cs_thick,err_iso_thick = stat_errors_neutron(f_name,"thick")
quad4_thin, err_quad4_thin = iso_cs_thin,err_iso_thin
quad4_medium, err_quad4_medium = iso_cs_medium,err_iso_medium
quad4_thick, err_quad4_thick = iso_cs_thick,err_iso_thick

fig, ax = plt.subplots()
#fig.tight_layout()
energy = [400,550,650,800]
ax.errorbar(energy,iso_cs_thick,yerr=err_iso_thick,label="thick target",color='red',marker="o",fmt="o")
energy = [405,555,655,805]
ax.errorbar(energy,iso_cs_medium,yerr=err_iso_medium,label="medium target",color='green',marker="v",fmt="o")
energy = [410,560,660,810]
ax.errorbar(energy,iso_cs_thin,yerr=err_iso_thin,label="thin target",color='blue',marker="s",fmt="o")
ax.legend()
ax.grid()
ax.set_xlabel("Beam Energy [AMeV]")
ax.set_ylabel("Cross Section Contribution [mbarn]")
ax.set_title(r'Isotope Correction $^{12}C$  versus $^{11}C/^{10}C$, quadrant IV, diagonal cut on MW12')
ax_coll.append(ax)
# Out:
# total error	 3.0662545294628365
# total error	 3.4964595296648855
# total error	 3.2148041107689607
# total error	 3.286285970929495
# total error	 1.718501641220125
# total error	 2.2033458364334773
# total error	 1.9648220078586491
# total error	 2.13544716950244
# total error	 0.9996825240044828
# total error	 1.3913784145524348
# total error	 1.2214437180022548
# total error	 1.2331968518359504
